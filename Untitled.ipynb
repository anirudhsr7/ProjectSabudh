# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('data.xlsx')

# %%
data.head()
# Out:
#    Sr.No.  FIR No.                 IPC Date of Offence Date of FIR  \
# 0       1        3  283,304-A,427,337       2017-01-02  2017-01-02
# 1       2        4           279,304-A      2017-01-06  2017-01-07
# 2       3        8       279,304-A,427      2017-01-20  2017-01-21
# 3       4       11           279,304-A      2017-01-20  2017-01-22
# 4       5       18       279,304-A,427      2017-02-01  2017-02-03
#
#    Police Station        Day Time of Offence First Vehicle  Fatalities  \
# 0  Kiratpur Sahib 1900-01-02        12:45:00     Bus/Truck           0
# 1  Kiratpur Sahib 1900-01-06        00:00:00       Unknown           0
# 2  Kiratpur Sahib 1900-01-06        20:30:00  Car/Jeep/Van           0
# 3  Kiratpur Sahib 1900-01-06        11:00:00   Two Wheeler           0
# 4  Kiratpur Sahib 1900-01-04        19:40:00     Bus/Truck           0
#
#       ...      Maneuver type as per FIR  Place/Location of Occurrence  \
# 0     ...                 Rough Driving                    Bharatgarh
# 1     ...                 Over Speeding                       Dolowal
# 2     ...                 Over Speeding                  Sarsa Nangal
# 3     ...                 Over Speeding                    Hardonimoh
# 4     ...                 Over Speeding                       Dolowal
#
#   Total Fatalities  Total Serious   Total Minor  Latitude Longitude  \
# 0                2               2            0   31.0987   76.6135
# 1                1               0            0   31.1844   76.5721
# 2                2               0            0   31.0619   76.5998
# 3                1               0            0   31.1607   76.5904
# 4                1               0            0   31.1844   76.5721
#
#    Road Name  Road Number Rural/Urban
# 0          NH      NH-205       Rural
# 1          NH      NH-205       Rural
# 2          NH      NH-205       Rural
# 3   Link Road   Link Road       Rural
# 4          NH      NH-205       Urban
#
# [5 rows x 29 columns]

# %%
X = data[['Type of Collision', 'Police Station', 'Total Fatalities']]

# %%
X['Type of Collision'] = [x.lower() for x in X['Type of Collision']]
# Out:
# C:\Users\Anirudh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X = X.rename(columns={'Type of Collision' : 'type_of_collision', 'Total Fatalities':'tot_fatalities', 
                     'Police Station':'police_station'})

# %%
X.head()
# Out:
#   type_of_collision  police_station  tot_fatalities
# 0     hit from back  Kiratpur Sahib               2
# 1       hit and run  Kiratpur Sahib               1
# 2       hit and run  Kiratpur Sahib               2
# 3           head on  Kiratpur Sahib               1
# 4     hit from back  Kiratpur Sahib               1

# %%
X['type_of_collision'].unique()
# Out:
# array(['hit from back', 'hit and run', 'head on', 'hit from side',
#        'hit pedestrian', 'unknown', 'hit cyclist', 'sideswipe ',
#        'hit fixed object', 'head on tail'], dtype=object)

# %%
X['police_station'].unique()
# Out:
# array(['Kiratpur Sahib', 'Chamkaur Sahib', 'City Ropar', 'Morinda',
#        'Nurpur Bedi', 'Sadar Roopnagar', 'Singh Bhagwantpura ',
#        'Anandpur Sahib ', 'Nangal'], dtype=object)

# %%
pol_stat = ['Kiratpur Sahib', 'Chamkaur Sahib', 'City Ropar', 'Morinda',
       'Nurpur Bedi', 'Sadar Roopnagar', 'Singh Bhagwantpura ',
       'Anandpur Sahib ', 'Nangal']

# %%
col_l = ['hit from back', 'hit and run', 
       'head on', 'hit from side','hit pedestrian', 
       'unknown', 'hit cyclist', 'sideswipe ',
       'hit fixed object', 'head on tail']

# %%
col_l_k = []
col_l_c = []
col_l_cr = []
col_l_m = []
col_l_nb = []
col_l_sr = []
col_l_sb = []
col_l_as = []
col_l_na = []

# %%
# def check(data):
    
#     col = data[''][i]
#     pol = data[1]
#     fat = data[2]
    
#     if pol == 'Kiratpur Sahib':
#         col_l_k.append(col)
#     elif pol == 'Chamkaur Sahib':
#         col_l_c.append(col)
#     elif pol == 'City Ropar':
#         col_l_cr.append(col)
#     elif pol == 'Morinda':
#         col_l_m.append(col)
#     elif pol == 'Nurpur Bedi':
#         col_l_nb.append(col)
#     elif pol == 'Sadar Roopnagar':
#         col_l_sr.append(col)
#     elif pol == 'Singh Bhagwantpura ':
#         col_l_sb.append(col)
#     elif pol == 'Anandpur Sahib ':
#         col_l_as.append(col)
#     elif pol == 'Nangal':
#         col_l_na.append(col)

# %%
X.shape
# Out:
# (217, 3)

# %%
for _, row in X.iterrows():
    pol = row['police_station']
    col = row['type_of_collision']
    
    
    if pol == 'Kiratpur Sahib':
        col_l_k.append(col)
    elif pol == 'Chamkaur Sahib':
        col_l_c.append(col)
    elif pol == 'City Ropar':
        col_l_cr.append(col)
    elif pol == 'Morinda':
        col_l_m.append(col)
    elif pol == 'Nurpur Bedi':
        col_l_nb.append(col)
    elif pol == 'Sadar Roopnagar':
        col_l_sr.append(col)
    elif pol == 'Singh Bhagwantpura ':
        col_l_sb.append(col)
    elif pol == 'Anandpur Sahib ':
        col_l_as.append(col)
    elif pol == 'Nangal':
        col_l_na.append(col)

# %%
list(set(col_l_k))
# Out:
# ['hit from back', 'hit from side', 'hit and run', 'head on']

# %%
col_l_k = list(set(col_l_k))
col_l_c = list(set(col_l_c))
col_l_cr = list(set(col_l_cr))
col_l_m = list(set(col_l_m))
col_l_nb = list(set(col_l_nb))
col_l_sr = list(set(col_l_sr))
col_l_sb = list(set(col_l_sb))
col_l_as = list(set(col_l_as))
col_l_na = list(set(col_l_na))

# %%
nt_col_k = [e for e in col_l if e not in col_l_k]
nt_col_c = [e for e in col_l if e not in col_l_c]
nt_col_cr = [e for e in col_l if e not in col_l_cr]
nt_col_m = [e for e in col_l if e not in col_l_m]
nt_col_nb = [e for e in col_l if e not in col_l_nb]
nt_col_sr = [e for e in col_l if e not in col_l_sr]
nt_col_sb = [e for e in col_l if e not in col_l_sb]
nt_col_as = [e for e in col_l if e not in col_l_as]
nt_col_na = [e for e in col_l if e not in col_l_na]

# %%
for i in range(1,len(nt_col_k)):
    print(nt_col_k[i])
    X = X.append(pd.DataFrame([[nt_col_k[i], 'Kiratpur Sahib', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)
# Out:
# unknown
# hit cyclist
# sideswipe
# hit fixed object
# head on tail

# %%
nt_col_k
# Out:
# ['hit pedestrian',
#  'unknown',
#  'hit cyclist',
#  'sideswipe ',
#  'hit fixed object',
#  'head on tail']

# %%
col_l_k
# Out:
# ['hit from back', 'hit from side', 'hit and run', 'head on']

# %%
for i in range(len(nt_col_c)):
    X = X.append(pd.DataFrame([[nt_col_c[i], 'Chamkaur Sahib', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_cr)):
    X = X.append(pd.DataFrame([[nt_col_cr[i], 'City Ropar', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_m)):
    X = X.append(pd.DataFrame([[nt_col_m[i], 'Morinda', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_nb)):
    X = X.append(pd.DataFrame([[nt_col_nb[i], 'Nurpur Bedi', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_sr)):
    X = X.append(pd.DataFrame([[nt_col_sr[i], 'Sadar Roopnagar', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_sb)):
    X = X.append(pd.DataFrame([[nt_col_sb[i], 'Singh Bhagwantpura ', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_as)):
    X = X.append(pd.DataFrame([[nt_col_as[i], 'Anandpur Sahib ', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in range(len(nt_col_na)):
    X = X.append(pd.DataFrame([[nt_col_na[i], 'Nangal', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
X['police_station'].unique()
# Out:
# array(['Kiratpur Sahib', 'Chamkaur Sahib', 'City Ropar', 'Morinda',
#        'Nurpur Bedi', 'Sadar Roopnagar', 'Singh Bhagwantpura ',
#        'Anandpur Sahib ', 'Nangal'], dtype=object)

# %%
X.groupby('police_station').first()
# Out:
#                     type_of_collision  tot_fatalities
# police_station
# Anandpur Sahib         hit pedestrian               1
# Chamkaur Sahib         hit pedestrian               0
# City Ropar                    head on               0
# Kiratpur Sahib          hit from back               2
# Morinda                       head on               1
# Nangal                        head on               0
# Nurpur Bedi                   head on               1
# Sadar Roopnagar        hit pedestrian               1
# Singh Bhagwantpura     hit pedestrian               1

# %%
X.tail()
# Out:
#     type_of_collision  police_station  tot_fatalities
# 224     hit from side  Chamkaur Sahib               0
# 225       hit cyclist  Chamkaur Sahib               0
# 226        sideswipe   Chamkaur Sahib               0
# 227  hit fixed object  Chamkaur Sahib               0
# 228      head on tail  Chamkaur Sahib               0

# %%
X.shape
# Out:
# (217, 3)

# %%
X.append(pd.DataFrame(nt_col_k[0], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-327-05d89e7e0e9a> in <module>()
# ----> 1 X.append(pd.DataFrame(nt_col_k[0], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     420                                          dtype=values.dtype, copy=False)
#     421             else:
# --> 422                 raise ValueError('DataFrame constructor not properly called!')
#     423
#     424         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
X = X.append(pd.DataFrame([[nt_col_k[0], 'Kiratpur Sahib', 0]], columns=['type_of_collision', 'police_station', 'tot_fatalities']), ignore_index=True)

# %%
for i in nt_col_k:
    print(i)
# Out:
# hit pedestrian
# unknown
# hit cyclist
# sideswipe
# hit fixed object
# head on tail

# %%
X.tail()
# Out:
#     type_of_collision   police_station  tot_fatalities
# 259           unknown  Anandpur Sahib                0
# 260       hit cyclist  Anandpur Sahib                0
# 261       hit and run           Nangal               0
# 262  hit fixed object           Nangal               0
# 263      head on tail           Nangal               0

# %%
nt_col_as
# Out:
# ['hit and run', 'hit from side', 'unknown', 'hit cyclist']

# %%
X.groupby(['police_station', 'type_of_collision']).first()
# Out:
#                                        tot_fatalities
# police_station      type_of_collision
# Anandpur Sahib      head on                         0
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     0
#                     hit fixed object                1
#                     hit from back                   1
#                     hit from side                   0
#                     hit pedestrian                  1
#                     sideswipe                       2
#                     unknown                         0
# Chamkaur Sahib      head on                         2
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     0
#                     hit fixed object                0
#                     hit from back                   2
#                     hit from side                   0
#                     hit pedestrian                  0
#                     sideswipe                       0
#                     unknown                         2
# City Ropar          head on                         0
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     1
#                     hit fixed object                0
#                     hit from back                   0
#                     hit from side                   0
#                     hit pedestrian                  1
#                     sideswipe                       0
#                     unknown                         0
# ...                                               ...
# Nurpur Bedi         head on                         1
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     0
#                     hit fixed object                0
#                     hit from back                   0
#                     hit from side                   0
#                     hit pedestrian                  0
#                     sideswipe                       0
#                     unknown                         3
# Sadar Roopnagar     head on                         1
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     0
#                     hit fixed object                0
#                     hit from back                   0
#                     hit from side                   0
#                     hit pedestrian                  1
#                     sideswipe                       0
#                     unknown                         0
# Singh Bhagwantpura  head on                         0
#                     head on tail                    0
#                     hit and run                     0
#                     hit cyclist                     1
#                     hit fixed object                0
#                     hit from back                   0
#                     hit from side                   0
#                     hit pedestrian                  1
#                     sideswipe                       0
#                     unknown                         0
#
# [89 rows x 1 columns]

# %%
x = X.groupby(['police_station', 'type_of_collision']).count()

# %%
# x = X.groupby(['police_station', 'type_of_collision']).tot_fatalities.value_counts()

# %%
x
# Out:
#                                        tot_fatalities
# police_station      type_of_collision
# Anandpur Sahib      head on                        11
#                     head on tail                    1
#                     hit fixed object                1
#                     hit from back                  10
#                     hit pedestrian                  2
#                     sideswipe                       1
# Chamkaur Sahib      head on                         9
#                     hit from back                   2
#                     hit pedestrian                  1
#                     unknown                         2
# City Ropar          head on                        12
#                     hit cyclist                     1
#                     hit fixed object                1
#                     hit from back                   9
#                     hit pedestrian                  5
#                     sideswipe                       8
# Kiratpur Sahib      head on                         9
#                     hit and run                    11
#                     hit from back                   5
#                     hit from side                   1
# Morinda             head on                        20
#                     hit pedestrian                  4
#                     sideswipe                       2
# Nangal              head on                        11
#                     hit cyclist                     3
#                     hit from back                   5
#                     hit from side                   4
#                     hit pedestrian                  2
#                     sideswipe                       1
#                     unknown                         3
# Nurpur Bedi         head on                        10
#                     hit pedestrian                  1
#                     unknown                         3
# Sadar Roopnagar     head on                        11
#                     hit cyclist                     4
#                     hit pedestrian                 10
# Singh Bhagwantpura  head on                         1
#                     hit and run                     1
#                     hit cyclist                     1
#                     hit from back                   6
#                     hit pedestrian                  5
#                     sideswipe                       7

# %%
x.groupby('police_station').ffill()
# Out:
#                                             police_station  tot_fatalities
# police_station      type_of_collision
# Anandpur Sahib      head on                Anandpur Sahib               11
#                     head on tail           Anandpur Sahib                1
#                     hit fixed object       Anandpur Sahib                1
#                     hit from back          Anandpur Sahib               10
#                     hit pedestrian         Anandpur Sahib                2
#                     sideswipe              Anandpur Sahib                1
# Chamkaur Sahib      head on                 Chamkaur Sahib               9
#                     hit from back           Chamkaur Sahib               2
#                     hit pedestrian          Chamkaur Sahib               1
#                     unknown                 Chamkaur Sahib               2
# City Ropar          head on                     City Ropar              12
#                     hit cyclist                 City Ropar               1
#                     hit fixed object            City Ropar               1
#                     hit from back               City Ropar               9
#                     hit pedestrian              City Ropar               5
#                     sideswipe                   City Ropar               8
# Kiratpur Sahib      head on                 Kiratpur Sahib               9
#                     hit and run             Kiratpur Sahib              11
#                     hit from back           Kiratpur Sahib               5
#                     hit from side           Kiratpur Sahib               1
# Morinda             head on                        Morinda              20
#                     hit pedestrian                 Morinda               4
#                     sideswipe                      Morinda               2
# Nangal              head on                         Nangal              11
#                     hit cyclist                     Nangal               3
#                     hit from back                   Nangal               5
#                     hit from side                   Nangal               4
#                     hit pedestrian                  Nangal               2
#                     sideswipe                       Nangal               1
#                     unknown                         Nangal               3
# Nurpur Bedi         head on                    Nurpur Bedi              10
#                     hit pedestrian             Nurpur Bedi               1
#                     unknown                    Nurpur Bedi               3
# Sadar Roopnagar     head on                Sadar Roopnagar              11
#                     hit cyclist            Sadar Roopnagar               4
#                     hit pedestrian         Sadar Roopnagar              10
# Singh Bhagwantpura  head on            Singh Bhagwantpura                1
#                     hit and run        Singh Bhagwantpura                1
#                     hit cyclist        Singh Bhagwantpura                1
#                     hit from back      Singh Bhagwantpura                6
#                     hit pedestrian     Singh Bhagwantpura                5
#                     sideswipe          Singh Bhagwantpura                7

# %%
for record in range(X.shape[0]):
    c.get_group(record.iloc[record])

# %%
c.get_group()

# %%
X.shape
# Out:
# (217, 3)

# %%
X['Type of Collision'] = [x.lower() for x in X['Type of Collision']]
# Out:
# C:\Users\Anirudh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X.head()
# Out:
#   Type of Collision  Police Station  Total Fatalities
# 0     hit from back  Kiratpur Sahib                 2
# 1       hit and run  Kiratpur Sahib                 1
# 2       hit and run  Kiratpur Sahib                 2
# 3           head on  Kiratpur Sahib                 1
# 4     hit from back  Kiratpur Sahib                 1

# %%
c['type_of_collision'].first()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-198-d36b7d90b26a> in <module>()
# ----> 1 c['type_of_collision'].first()
#
# AttributeError: 'numpy.int64' object has no attribute 'first'
